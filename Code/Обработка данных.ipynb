# %% [markdown]
# # Загрузка файлов

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
import os

path="/content/drive/MyDrive/test/original" #Подставить свой путь

files = []
# r=root, d=directories, f = files
print ('Список файлов \n')
for r, d, f in os.walk(path):
    for file in f:
        if file.endswith(('.doc', '.docx')):
            files.append (os.path.join(r, file))
            print(os.path.join(r, file))
# Out:
# Список файлов
#
# /content/drive/MyDrive/test/original/Стратегия Белгородской области до 2025.docx
# /content/drive/MyDrive/test/original/Стратегия Владимирской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Волгоградской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Воронежской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Еврейской автономной области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Забайкальского края до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Ивановской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Иркутской области до 2036.docx
# /content/drive/MyDrive/test/original/Стратегия Кабардино-Балкарской Республики до 2040.docx
# /content/drive/MyDrive/test/original/Стратегия Калининградской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Калужской области до 2040.docx
# /content/drive/MyDrive/test/original/Стратегия Камчатского края до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Карачаево-Черкесской Республики до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Кемеровской области - Кузбасса до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Кировской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Костромской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Красноярского края до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Курганской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Ленинградской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Липецкой области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Московской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Ненецкого автономного округа до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Новогородской области до 2026.docx
# /content/drive/MyDrive/test/original/Стратегия Новосибирской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Омской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Оренбургской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Пензенской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Пермского края до 2026.docx
# /content/drive/MyDrive/test/original/Стратегия Приморского края до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Псковской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Адыгея до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Алтай до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Башкортостан до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Бурятия до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Дагестан до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Ингушетия до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Калмыкия до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Карелия до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Коми до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Крым до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Марий Эл до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Мордовия до 2025.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Саха (Якутия) до 2032.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Северная Осетия - Алания до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Татарстан до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Тыва до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Республики Хакасия до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Ростовской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Рязанской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Самарской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Орловской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Санкт-Петербурга до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Саратовской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Сахалинской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Свердловской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Севастополя до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Смоленской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Ставропольского края до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Тамбовской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Тверской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Томской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Тульской области до 2026'.docx
# /content/drive/MyDrive/test/original/Стратегия Ульяновской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Хабаровского края до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Ханты-Мансийского автономного округа - Югры до 2036.docx
# /content/drive/MyDrive/test/original/Стратегия Чеченской Республики до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Чувашской Республики до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Чукотского автономного округа до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Ямало-Ненецкого автономного округа до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Ярославской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Брянской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Вологодской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Краснодарского края до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Курской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Магаданской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Мурманской области до 2025.docx
# /content/drive/MyDrive/test/original/Стратегия Нижегородской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Тюменской области до 2030.docx
# /content/drive/MyDrive/test/original/Стратегия Удмуртской Республики до 2025.docx
# /content/drive/MyDrive/test/original/Стратегия Челябинской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Амурской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Алтайского края до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Астраханской области до 2035.docx
# /content/drive/MyDrive/test/original/Стратегия Архангельской области до 2035.docx

# %% [markdown]
# # Изменение заголовка на транслит

# %%
# !pip install transliterate
# !pip install python-docx
# Out:
# Collecting transliterate
#   Downloading transliterate-1.10.2-py2.py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 937.7 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from transliterate) (1.16.0)
# Installing collected packages: transliterate
# Successfully installed transliterate-1.10.2
# Collecting python-docx
#   Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.5.0)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.0

# %%
from transliterate import translit
from docx import Document
from docx.shared import Inches

#print (translit(u"Лорем ипсум долор сит амет", "ru", reversed=True))

# %%
new_names_list = []
for file in files:
  new_name = translit(file, "ru", reversed=True).replace(" ", "_")
  new_name = new_name.replace("original", "new_names")
  new_names_list.append(new_name)
  document = Document(file)
  document.save(new_name)
  print (new_name)
# Out:
# /content/drive/MyDrive/test/new_names/Strategija_Belgorodskoĭ_oblasti_do_2025.docx
# /content/drive/MyDrive/test/new_names/Strategija_Vladimirskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Volgogradskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Voronezhskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Evreĭskoĭ_avtonomnoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Zabaĭkal'skogo_kraja_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Ivanovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Irkutskoĭ_oblasti_do_2036.docx
# /content/drive/MyDrive/test/new_names/Strategija_Kabardino-Balkarskoĭ_Respubliki_do_2040.docx
# /content/drive/MyDrive/test/new_names/Strategija_Kaliningradskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Kaluzhskoĭ_oblasti_do_2040.docx
# /content/drive/MyDrive/test/new_names/Strategija_Kamchatskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Karachaevo-Cherkesskoĭ_Respubliki_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Kemerovskoĭ_oblasti_-_Kuzbassa_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Kirovskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Kostromskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Krasnojarskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Kurganskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Leningradskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Lipetskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Moskovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Nenetskogo_avtonomnogo_okruga_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Novogorodskoĭ_oblasti_do_2026.docx
# /content/drive/MyDrive/test/new_names/Strategija_Novosibirskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Omskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Orenburgskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Penzenskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Permskogo_kraja_do_2026.docx
# /content/drive/MyDrive/test/new_names/Strategija_Primorskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Pskovskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Adygeja_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Altaĭ_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Bashkortostan_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Burjatija_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Dagestan_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Ingushetija_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Kalmykija_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Karelija_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Komi_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Krym_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Mariĭ_El_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Mordovija_do_2025.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Saha_(Jakutija)_do_2032.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Severnaja_Osetija_-_Alanija_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Tatarstan_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Tyva_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Hakasija_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Rostovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Rjazanskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Samarskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Orlovskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Sankt-Peterburga_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Saratovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Sahalinskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Sverdlovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Sevastopolja_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Smolenskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Stavropol'skogo_kraja_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Tambovskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Tverskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Tomskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Tul'skoĭ_oblasti_do_2026'.docx
# /content/drive/MyDrive/test/new_names/Strategija_Ul'janovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Habarovskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Hanty-Mansiĭskogo_avtonomnogo_okruga_-_Jugry_do_2036.docx
# /content/drive/MyDrive/test/new_names/Strategija_Chechenskoĭ_Respubliki_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Chuvashskoĭ_Respubliki_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Chukotskogo_avtonomnogo_okruga_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Jamalo-Nenetskogo_avtonomnogo_okruga_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Jaroslavskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Brjanskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Vologodskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Krasnodarskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Kurskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Magadanskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Murmanskoĭ_oblasti_do_2025.docx
# /content/drive/MyDrive/test/new_names/Strategija_Nizhegorodskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Tjumenskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/new_names/Strategija_Udmurtskoĭ_Respubliki_do_2025.docx
# /content/drive/MyDrive/test/new_names/Strategija_Cheljabinskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Amurskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Altaĭskogo_kraja_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Astrahanskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/new_names/Strategija_Arhangel'skoĭ_oblasti_do_2035.docx

# %% [markdown]
# ## Конвертация docx в txt

# %%
# !pip install pypandoc
# Out:
# Collecting pypandoc
#   Downloading pypandoc-1.12-py3-none-any.whl (20 kB)
# Installing collected packages: pypandoc
# Successfully installed pypandoc-1.12

# %%
import pypandoc

path_conv = "/content/drive/MyDrive/test/conv/"
txt_files_list = []

for doc_file_name in new_names_list:
  file_name = doc_file_name.split("/")[-1]
  txtFilename = path_conv + file_name.split(".")[0] + ".txt"
  txt_files_list.append(txtFilename)

  print (doc_file_name)
  print (txtFilename)

  #output = pypandoc.convert_file(docxFilename, 'plain', txtFilename)
  output =  pypandoc.convert_file(doc_file_name, 'plain',extra_args=('--standalone','--wrap=none'), outputfile=txtFilename)
  assert output == ""
# Out:
# /content/drive/MyDrive/test/new_names/Strategija_Belgorodskoĭ_oblasti_do_2025.docx
# /content/drive/MyDrive/test/conv/Strategija_Belgorodskoĭ_oblasti_do_2025.txt
# /content/drive/MyDrive/test/new_names/Strategija_Vladimirskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Vladimirskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Volgogradskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Volgogradskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Voronezhskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Voronezhskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Evreĭskoĭ_avtonomnoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Evreĭskoĭ_avtonomnoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Zabaĭkal'skogo_kraja_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Zabaĭkal'skogo_kraja_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Ivanovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Ivanovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Irkutskoĭ_oblasti_do_2036.docx
# /content/drive/MyDrive/test/conv/Strategija_Irkutskoĭ_oblasti_do_2036.txt
# /content/drive/MyDrive/test/new_names/Strategija_Kabardino-Balkarskoĭ_Respubliki_do_2040.docx
# /content/drive/MyDrive/test/conv/Strategija_Kabardino-Balkarskoĭ_Respubliki_do_2040.txt
# /content/drive/MyDrive/test/new_names/Strategija_Kaliningradskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Kaliningradskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Kaluzhskoĭ_oblasti_do_2040.docx
# /content/drive/MyDrive/test/conv/Strategija_Kaluzhskoĭ_oblasti_do_2040.txt
# /content/drive/MyDrive/test/new_names/Strategija_Kamchatskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Kamchatskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Karachaevo-Cherkesskoĭ_Respubliki_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Karachaevo-Cherkesskoĭ_Respubliki_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Kemerovskoĭ_oblasti_-_Kuzbassa_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Kemerovskoĭ_oblasti_-_Kuzbassa_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Kirovskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Kirovskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Kostromskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Kostromskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Krasnojarskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Krasnojarskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Kurganskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Kurganskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Leningradskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Leningradskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Lipetskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Lipetskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Moskovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Moskovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Nenetskogo_avtonomnogo_okruga_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Nenetskogo_avtonomnogo_okruga_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Novogorodskoĭ_oblasti_do_2026.docx
# /content/drive/MyDrive/test/conv/Strategija_Novogorodskoĭ_oblasti_do_2026.txt
# /content/drive/MyDrive/test/new_names/Strategija_Novosibirskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Novosibirskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Omskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Omskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Orenburgskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Orenburgskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Penzenskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Penzenskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Permskogo_kraja_do_2026.docx
# /content/drive/MyDrive/test/conv/Strategija_Permskogo_kraja_do_2026.txt
# /content/drive/MyDrive/test/new_names/Strategija_Primorskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Primorskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Pskovskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Pskovskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Adygeja_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Adygeja_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Altaĭ_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Altaĭ_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Bashkortostan_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Bashkortostan_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Burjatija_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Burjatija_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Dagestan_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Dagestan_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Ingushetija_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Ingushetija_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Kalmykija_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Kalmykija_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Karelija_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Karelija_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Komi_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Komi_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Krym_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Krym_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Mariĭ_El_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Mariĭ_El_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Mordovija_do_2025.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Mordovija_do_2025.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Saha_(Jakutija)_do_2032.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Saha_(Jakutija)_do_2032.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Severnaja_Osetija_-_Alanija_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Severnaja_Osetija_-_Alanija_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Tatarstan_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Tatarstan_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Tyva_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Tyva_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Respubliki_Hakasija_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Hakasija_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Rostovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Rostovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Rjazanskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Rjazanskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Samarskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Samarskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Orlovskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Orlovskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Sankt-Peterburga_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Sankt-Peterburga_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Saratovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Saratovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Sahalinskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Sahalinskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Sverdlovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Sverdlovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Sevastopolja_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Sevastopolja_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Smolenskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Smolenskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Stavropol'skogo_kraja_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Stavropol'skogo_kraja_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Tambovskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Tambovskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Tverskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Tverskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Tomskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Tomskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Tul'skoĭ_oblasti_do_2026'.docx
# /content/drive/MyDrive/test/conv/Strategija_Tul'skoĭ_oblasti_do_2026'.txt
# /content/drive/MyDrive/test/new_names/Strategija_Ul'janovskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Ul'janovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Habarovskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Habarovskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Hanty-Mansiĭskogo_avtonomnogo_okruga_-_Jugry_do_2036.docx
# /content/drive/MyDrive/test/conv/Strategija_Hanty-Mansiĭskogo_avtonomnogo_okruga_-_Jugry_do_2036.txt
# /content/drive/MyDrive/test/new_names/Strategija_Chechenskoĭ_Respubliki_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Chechenskoĭ_Respubliki_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Chuvashskoĭ_Respubliki_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Chuvashskoĭ_Respubliki_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Chukotskogo_avtonomnogo_okruga_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Chukotskogo_avtonomnogo_okruga_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Jamalo-Nenetskogo_avtonomnogo_okruga_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Jamalo-Nenetskogo_avtonomnogo_okruga_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Jaroslavskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Jaroslavskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Brjanskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Brjanskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Vologodskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Vologodskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Krasnodarskogo_kraja_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Krasnodarskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Kurskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Kurskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Magadanskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Magadanskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Murmanskoĭ_oblasti_do_2025.docx
# /content/drive/MyDrive/test/conv/Strategija_Murmanskoĭ_oblasti_do_2025.txt
# /content/drive/MyDrive/test/new_names/Strategija_Nizhegorodskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Nizhegorodskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Tjumenskoĭ_oblasti_do_2030.docx
# /content/drive/MyDrive/test/conv/Strategija_Tjumenskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/new_names/Strategija_Udmurtskoĭ_Respubliki_do_2025.docx
# /content/drive/MyDrive/test/conv/Strategija_Udmurtskoĭ_Respubliki_do_2025.txt
# /content/drive/MyDrive/test/new_names/Strategija_Cheljabinskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Cheljabinskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Amurskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Amurskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Altaĭskogo_kraja_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Altaĭskogo_kraja_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Astrahanskoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Astrahanskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/new_names/Strategija_Arhangel'skoĭ_oblasti_do_2035.docx
# /content/drive/MyDrive/test/conv/Strategija_Arhangel'skoĭ_oblasti_do_2035.txt

# %% [markdown]
# ### Чистка txt

# %%
delete_list = [" Документ предоставлен ", " КонсультантПлюс: ", " КонсультантПлюс ", " [] ", " []\n", "\n[] ", "\r[]\r", "+-", " -- ", " -+", "+=",
               "=+", " = ", " | ", " + ", " -", "\r\n []", "\n []", "\n\n", "\n[]\n", "$[]$"]

# %%
for infile in txt_files_list:
    print (infile)

    # Read in the file
    with open(infile, 'r') as file:
      filedata = file.read()

    # Replace the target string
    for word in delete_list:
      filedata = filedata.replace(word, "")

    outfile = infile
    # Write the file out again
    with open(outfile, 'w') as file:
      file.write(filedata)
# Out:
# /content/drive/MyDrive/test/conv/Strategija_Belgorodskoĭ_oblasti_do_2025.txt
# /content/drive/MyDrive/test/conv/Strategija_Vladimirskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Volgogradskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Voronezhskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Evreĭskoĭ_avtonomnoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Zabaĭkal'skogo_kraja_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Ivanovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Irkutskoĭ_oblasti_do_2036.txt
# /content/drive/MyDrive/test/conv/Strategija_Kabardino-Balkarskoĭ_Respubliki_do_2040.txt
# /content/drive/MyDrive/test/conv/Strategija_Kaliningradskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Kaluzhskoĭ_oblasti_do_2040.txt
# /content/drive/MyDrive/test/conv/Strategija_Kamchatskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Karachaevo-Cherkesskoĭ_Respubliki_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Kemerovskoĭ_oblasti_-_Kuzbassa_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Kirovskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Kostromskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Krasnojarskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Kurganskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Leningradskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Lipetskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Moskovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Nenetskogo_avtonomnogo_okruga_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Novogorodskoĭ_oblasti_do_2026.txt
# /content/drive/MyDrive/test/conv/Strategija_Novosibirskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Omskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Orenburgskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Penzenskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Permskogo_kraja_do_2026.txt
# /content/drive/MyDrive/test/conv/Strategija_Primorskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Pskovskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Adygeja_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Altaĭ_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Bashkortostan_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Burjatija_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Dagestan_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Ingushetija_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Kalmykija_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Karelija_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Komi_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Krym_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Mariĭ_El_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Mordovija_do_2025.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Saha_(Jakutija)_do_2032.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Severnaja_Osetija_-_Alanija_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Tatarstan_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Tyva_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Respubliki_Hakasija_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Rostovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Rjazanskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Samarskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Orlovskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Sankt-Peterburga_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Saratovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Sahalinskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Sverdlovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Sevastopolja_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Smolenskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Stavropol'skogo_kraja_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Tambovskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Tverskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Tomskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Tul'skoĭ_oblasti_do_2026'.txt
# /content/drive/MyDrive/test/conv/Strategija_Ul'janovskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Habarovskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Hanty-Mansiĭskogo_avtonomnogo_okruga_-_Jugry_do_2036.txt
# /content/drive/MyDrive/test/conv/Strategija_Chechenskoĭ_Respubliki_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Chuvashskoĭ_Respubliki_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Chukotskogo_avtonomnogo_okruga_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Jamalo-Nenetskogo_avtonomnogo_okruga_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Jaroslavskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Brjanskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Vologodskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Krasnodarskogo_kraja_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Kurskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Magadanskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Murmanskoĭ_oblasti_do_2025.txt
# /content/drive/MyDrive/test/conv/Strategija_Nizhegorodskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Tjumenskoĭ_oblasti_do_2030.txt
# /content/drive/MyDrive/test/conv/Strategija_Udmurtskoĭ_Respubliki_do_2025.txt
# /content/drive/MyDrive/test/conv/Strategija_Cheljabinskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Amurskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Altaĭskogo_kraja_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Astrahanskoĭ_oblasti_do_2035.txt
# /content/drive/MyDrive/test/conv/Strategija_Arhangel'skoĭ_oblasti_do_2035.txt

# %% [markdown]
# #Формирование оглавления

# %%
from docx.oxml.ns import qn
from docx.oxml import OxmlElement

# %%
file = new_names_list[2]
document = Document(file)

# %%
body_element = document._body._body
print(body_element.xml[:1000])
# Out:
# <w:body xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:cx="http://schemas.microsoft.com/office/drawing/2014/chartex" xmlns:cx1="http://schemas.microsoft.com/office/drawing/2015/9/8/chartex" xmlns:cx2="http://schemas.microsoft.com/office/drawing/2015/10/21/chartex" xmlns:cx3="http://schemas.microsoft.com/office/drawing/2016/5/9/chartex" xmlns:cx4="http://schemas.microsoft.com/office/drawing/2016/5/10/chartex" xmlns:cx5="http://schemas.microsoft.com/office/drawing/2016/5/11/chartex" xmlns:cx6="http://schemas.microsoft.com/office/drawing/2016/5/12/chartex" xmlns:cx7="http://schemas.microsoft.com/office/drawing/2016/5/13/chartex" xmlns:cx8="http://schemas.microsoft.com/office/drawing/2016/5/14/chartex" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:aink="http://schemas.microsoft.com/office/drawing/2016/ink" xmlns:am3d="http://schemas.microsoft.com/offic

# %%
# !pip install docxcompose
# Out:
# Collecting docxcompose
#   Downloading docxcompose-1.4.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from docxcompose) (4.9.3)
# Requirement already satisfied: python-docx>=0.8.8 in /usr/local/lib/python3.10/dist-packages (from docxcompose) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from docxcompose) (67.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from docxcompose) (1.16.0)
# Requirement already satisfied: babel in /usr/local/lib/python3.10/dist-packages (from docxcompose) (2.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from python-docx>=0.8.8->docxcompose) (4.5.0)
# Building wheels for collected packages: docxcompose
#   Building wheel for docxcompose (setup.py) ... done
#   Created wheel for docxcompose: filename=docxcompose-1.4.0-py3-none-any.whl size=23267 sha256=2a81f2888d44d58dac6105f2cdbebaef1d8cfd1b52184b6a2fa148026d67314c
#   Stored in directory: /root/.cache/pip/wheels/28/0e/78/2dc28f2d5b192d1a3ec237ec60e9d65654a078dfe07ce3a714
# Successfully built docxcompose
# Installing collected packages: docxcompose
# Successfully installed docxcompose-1.4.0

# %%
###Import all necessary packages
from docx.opc.constants import RELATIONSHIP_TYPE as RT
from docx import *
from docx.text.paragraph import Paragraph
from docx.text.paragraph import Run
import xml.etree.ElementTree as ET
from docx.document import Document as doctwo
from docx.oxml.table import CT_Tbl
from docx.oxml.text.paragraph import CT_P
from docx.table import _Cell, Table
from docx.text.paragraph import Paragraph
from docx.shared import Pt
from docxcompose.composer import Composer
from docx import Document as Document_compose
import pandas as pd
from xml.etree import ElementTree
from io import StringIO
import io
import csv
import base64


#Load the docx file into document object. You can input your own docx file in this step by changing the input path below:
document = Document(file)


##This function extracts the tables and paragraphs from the document object
def iter_block_items(parent):
    """
    Yield each paragraph and table child within *parent*, in document order.
    Each returned value is an instance of either Table or Paragraph. *parent*
    would most commonly be a reference to a main Document object, but
    also works for a _Cell object, which itself can contain paragraphs and tables.
    """
    if isinstance(parent, doctwo):
        parent_elm = parent.element.body
    elif isinstance(parent, _Cell):
        parent_elm = parent._tc
    else:
        raise ValueError("something's not right")

    for child in parent_elm.iterchildren():
        if isinstance(child, CT_P):
            yield Paragraph(child, parent)
        elif isinstance(child, CT_Tbl):
            yield Table(child, parent)


#This function extracts the table from the document object as a dataframe
def read_docx_tables(tab_id=None, **kwargs):
    """
    parse table(s) from a Word Document (.docx) into Pandas DataFrame(s)

    Parameters:
        filename:   file name of a Word Document

        tab_id:     parse a single table with the index: [tab_id] (counting from 0).
                    When [None] - return a list of DataFrames (parse all tables)

        kwargs:     arguments to pass to `pd.read_csv()` function

    Return: a single DataFrame if tab_id != None or a list of DataFrames otherwise
    """
    def read_docx_tab(tab, **kwargs):
        vf = io.StringIO()
        writer = csv.writer(vf)
        for row in tab.rows:
            writer.writerow(cell.text for cell in row.cells)
        vf.seek(0)
        return pd.read_csv(vf, **kwargs)

#    doc = Document(filename)
    if tab_id is None:
        return [read_docx_tab(tab, **kwargs) for tab in document.tables]
    else:
        try:
            return read_docx_tab(document.tables[tab_id], **kwargs)
        except IndexError:
            print('Error: specified [tab_id]: {}  does not exist.'.format(tab_id))
            raise



#The combined_df dataframe will store all the content in document order including images, tables and paragraphs.
#If the content is an image or a table, it has to be referenced from image_df for images and table_list for tables using the corresponding image or table id that is stored in combined_df
#And if the content is paragraph, the paragraph text will be stored in combined_df
combined_df = pd.DataFrame(columns=['para_text','table_id','style'])
table_mod = pd.DataFrame(columns=['string_value','table_id'])

#The image_df will consist of base64 encoded image data of all the images in the document
image_df = pd.DataFrame(columns=['image_index','image_rID','image_filename','image_base64_string'])

#The table_list is a list consisting of all the tables in the document
table_list=[]
xml_list=[]

i=0
imagecounter = 0


blockxmlstring = ''
for block in iter_block_items(document):
    if 'text' in str(block):
        isappend = False

        runboldtext = ''
        for run in block.runs:
            if run.bold:
                runboldtext = runboldtext + run.text

        style = str(block.style.name)

        appendtxt = str(block.text)
        appendtxt = appendtxt.replace("\n","")
        appendtxt = appendtxt.replace("\r","")
        tabid = 'Novalue'
        paragraph_split = appendtxt.lower().split()

        isappend = True
        for run in block.runs:
            xmlstr = str(run.element.xml)
            my_namespaces = dict([node for _, node in ElementTree.iterparse(StringIO(xmlstr), events=['start-ns'])])
            root = ET.fromstring(xmlstr)
            #Check if pic is there in the xml of the element. If yes, then extract the image data
            if 'pic:pic' in xmlstr:
                xml_list.append(xmlstr)
                for pic in root.findall('.//pic:pic', my_namespaces):
                    cNvPr_elem = pic.find("pic:nvPicPr/pic:cNvPr", my_namespaces)
                    name_attr = cNvPr_elem.get("name")
                    blip_elem = pic.find("pic:blipFill/a:blip", my_namespaces)
                    embed_attr = blip_elem.get("{http://schemas.openxmlformats.org/officeDocument/2006/relationships}embed")
                    isappend = True
                    appendtxt = str('Document_Imagefile/' + name_attr + '/' + embed_attr + '/' + str(imagecounter))
                    document_part = document.part
                    image_part = document_part.related_parts[embed_attr]
                    image_base64 = base64.b64encode(image_part._blob)
                    image_base64 = image_base64.decode()
                    dftemp = pd.DataFrame({'image_index':[imagecounter],'image_rID':[embed_attr],'image_filename':[name_attr],'image_base64_string':[image_base64]})
                    image_df = image_df.append(dftemp,sort=False)
                    style = 'Novalue'
                imagecounter = imagecounter + 1

    elif 'table' in str(block):
        isappend = True
        style = 'Novalue'
        appendtxt = str(block)
        tabid = i
        dfs = read_docx_tables(tab_id=i)
        dftemp = pd.DataFrame({'para_text':[appendtxt],'table_id':[i],'style':[style]})
        table_mod = table_mod.append(dftemp,sort=False)
        table_list.append(dfs)
        i=i+1
    if isappend:
            dftemp = pd.DataFrame({'para_text':[appendtxt],'table_id':[tabid],'style':[style]})
            combined_df=combined_df.append(dftemp,sort=False)

combined_df = combined_df.reset_index(drop=True)
image_df = image_df.reset_index(drop=True)
# Out:
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:150: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table_mod = table_mod.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:139: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   image_df = image_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:139: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   image_df = image_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:139: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   image_df = image_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# ...
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:150: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table_mod = table_mod.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:150: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table_mod = table_mod.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:139: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   image_df = image_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:150: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table_mod = table_mod.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:139: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   image_df = image_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:139: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   image_df = image_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:150: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table_mod = table_mod.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)
# <ipython-input-15-a51871813f29>:155: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df=combined_df.append(dftemp,sort=False)

# %%
combined_df
# Out:
#                                         para_text table_id              style
# 0                                                  Novalue  ConsPlusTitlePage
# 1                                                  Novalue             Normal
# 2     <docx.table.Table object at 0x7a9246476020>        0            Novalue
# 3                                                  Novalue     ConsPlusNormal
# 4                                                  Novalue     ConsPlusNormal
# ...                                           ...      ...                ...
# 1569  <docx.table.Table object at 0x7a924645bd90>       14            Novalue
# 1570                                               Novalue     ConsPlusNormal
# 1571                                               Novalue     ConsPlusNormal
# 1572                                               Novalue     ConsPlusNormal
# 1573                                               Novalue             Normal
#
# [1574 rows x 3 columns]

# %%
combined_df['style'].unique()
# Out:
# array(['ConsPlusTitlePage', 'Normal', 'Novalue', 'ConsPlusNormal',
#        'ConsPlusTitle'], dtype=object)

# %%
combined_df[(combined_df['style']== 'ConsPlusTitle') & (combined_df['para_text'] != '') ]
# Out:
#                                               para_text table_id  \
# 5                                                 ЗАКОН  Novalue
# 6                                 ВОЛГОГРАДСКОЙ ОБЛАСТИ  Novalue
# 8         О СТРАТЕГИИ СОЦИАЛЬНО-ЭКОНОМИЧЕСКОГО РАЗВИТИЯ  Novalue
# 9                    ВОЛГОГРАДСКОЙ ОБЛАСТИ ДО 2030 ГОДА  Novalue
# 16                                             Статья 1  Novalue
# ...                                                 ...      ...
# 1538  и их частей в территориальные зоны с точки зре...  Novalue
# 1539                                           развития  Novalue
# 1554  Рисунок 1. Центры экономического роста Волгогр...  Novalue
# 1560  Рисунок 2. Специализация городских округов и м...  Novalue
# 1561                      районов Волгоградской области  Novalue
#
#               style
# 5     ConsPlusTitle
# 6     ConsPlusTitle
# 8     ConsPlusTitle
# 9     ConsPlusTitle
# 16    ConsPlusTitle
# ...             ...
# 1538  ConsPlusTitle
# 1539  ConsPlusTitle
# 1554  ConsPlusTitle
# 1560  ConsPlusTitle
# 1561  ConsPlusTitle
#
# [80 rows x 3 columns]
